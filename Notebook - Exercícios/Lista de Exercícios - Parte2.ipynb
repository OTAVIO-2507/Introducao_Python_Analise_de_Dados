# %% [markdown]
# 1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
numero_1 = float(input('Digite o primeiro número: '))
numero_2 = float(input('Digite o segundo número: '))
if numero_1 > numero_2:
  print(f'O maior número é {numero_1}')
elif numero_2 > numero_1:
  print(f'O maior número é {numero_2}')
else:
  print('Os dois números são iguais')
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 5
# Os dois números são iguais

# %% [markdown]
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
percentual = float(input('Digite o percentual de crescimento de produção de uma empresa: '))
if percentual > 0:
  print(f'Houve cresciemento de {percentual}%')
elif percentual < 0:
  print(f'Houve decrescimento de {percentual}%')
else:
  print('Não houve mudança no percentual de crescimento')
# Out:
# Digite o percentual de crescimento de produção de uma empresa: 0
# Não houve mudança no percentual de crescimento

# %% [markdown]
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
letras = input('Digite uma letra: ')
vogais = 'aeiou'
if letras in vogais:
  print(f'{letras} é uma vogal')
elif letras.isalpha() and letras not in vogais:
  print(f'{letras} é uma consoante')
else:
  print('Não é uma vogal nem consoante')
# Out:
# Digite uma letra: 1
# Não é uma vogal nem consoante

# %% [markdown]
# 4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
valores_medios1 = float(input('Digite o preço do primeiro ano: '))
valores_medios2 = float(input('Digite o preço do Segundo ano: '))
valores_medios3 = float(input('Digite o preço do Terceiro ano: '))

if valores_medios1 > valores_medios2 > valores_medios3:
  print(f'R${valores_medios1} é o maior valor e R${valores_medios3} é o menor valor')
elif valores_medios2 > valores_medios1 > valores_medios3:
  print(f'R${valores_medios2} é o maior valor e R${valores_medios3} é o menor valor')
elif valores_medios3 > valores_medios1 > valores_medios2:
  print(f'R${valores_medios3} é o maior valor e R${valores_medios2} é o menor valor')
elif valores_medios3 > valores_medios2 > valores_medios1:
  print(f'R${valores_medios3} é o maior valor e R${valores_medios1} é o menor valor')
else:
  print('Os valores são iguais')
# Out:
# Digite o preço do primeiro ano: 2000
# Digite o preço do Segundo ano: 1900
# Digite o preço do Terceiro ano: 1800
# R$2000.0 é o maior valor e R$1800.0 é o menor valor

# %% [markdown]
# 5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
produto1 = float(input('Digite o preço do primeiro produto: '))
produto2 = float(input('Digite o preço do segundo produto: '))
produto3 = float(input('Digite o preço do terceiro produto: '))

if produto1 > produto2 > produto3:
  print(f'O produto mais barato é o produto3 que custa {produto3}')
elif produto1 > produto3 > produto2:
  print(f'O produto mais barato é o produto2 que custa {produto2}')
elif produto2 > produto3 > produto1:
  print(f'O produto mais barato é o produto1 que custa {produto1}')
elif produto2 > produto1 > produto3:
  print(f'O produto mais barato é o produto3 que custa {produto3}')
elif produto3 > produto2 > produto1:
  print(f'O produto mais barato é o produto1 que custa {produto1}')
elif produto3 > produto1 > produto2:
  print(f'O produto mais barato é o produto2 que custa {produto2}')
else:
  print(f'Os produtos tem o mesmo preço')
# Out:
# Digite o preço do primeiro produto: 49
# Digite o preço do segundo produto: 50
# Digite o preço do terceiro produto: 51
# O produto mais barato é o produto1 que custa 49.0

# %% [markdown]
# 6) Escreva um programa que leia três números e os exiba em ordem decrescente.

# %%
n1 = float(input('Digite o n1: '))
n2 = float(input('Digite o n2: '))
n3 = float(input('Digite o n3: '))

if n1 > n2 > n3:
  print(n1, n2, n3)
elif n2 > n1 > n3:
  print(n2, n1, n3)
elif n3 > n2 > n1:
  print(n3, n2, n1)
elif n1 > n3 > n1:
  print(n1, n3, n2)
elif n2 > n3 > n1:
  print(n2, n3, n1)
elif n3 > n1 > n2:
  print(n3, n1, n2)
else:
  print('Os valroes são iguais')
# Out:
# Digite o n1: 15
# Digite o n2: 20
# Digite o n3: 2
# 20.0 15.0 2.0

# %% [markdown]
# 7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
Turno_Aluno = input('Qual turno a você estuda ("manhã", "tarde" ou "noite"): ')
Turnos_existentes = ('manhã, tarde, noite')
if Turno_Aluno == 'manhã':
  print('Bom Dia!')
elif Turno_Aluno == 'tarde':
  print('Boa Tarde!')
elif Turno_Aluno  == 'noite':
  print('Boa Noite!')
else:
  print('Valor inválido')
# Out:
# Qual turno a você estuda ("manhã", "tarde" ou "noite"): manhã
# Bom Dia!

# %% [markdown]
# 8) Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
n1 = int(input('Digite um número inteiro: '))
if n1 % 2 == 0:
  print('Esse número é par')
else:
  print('Esse número é impar')

# %% [markdown]
# 9) Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
n1 = float(input('Digite um número: '))
if n1 % 1 == 0:
  print('Esse número é inteiro')
else:
  print('Esse número é um decimal')
# Out:
# Digite um número: 4
# Esse número é inteiro

# %% [markdown]
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
saber = input('Gostaria de saber se é (par ou impar), (positivo ou negativo), (inteiro ou decimal): ')
n1 = float(input('Digite o número 1: '))
n2 = float(input('Digite o número 2: '))

if saber == 'par ou impar':
  if n1 % 2 == 0 and n2 % 2 == 0:
    print(f'{n1} Esse número é par e {n2} também é par')
  elif n1 % 2 != 0 and n2 % 2 != 0:
    print(f'{n1} Esse número é impar e {n2} também é impar')
  elif n1 % 2 != 0 and n2 % 2 == 0:
    print(f'{n1} Esse número é impar e {n2} é par')
  elif n1 % 2 == 0 and n2 % 2 != 0:
    print(f'{n1} Esse número é par e {n2} é impar')
  else:
    print('Esse valor não é um número')

elif saber == 'positivo ou negativo':
  if n1 > 0 and n2 > 0:
    print(f'{n1} é positivo e {n2} também é positivo')
  elif n1 < 0 and n2 < 0:
    print(f'{n1} é negativo e {n2} também é negativo')
  elif n1 > 0 and n2 < 0:
    print(f'{n1} é positivo e {n2} é negativo')
  elif n1 < 0 and n2 > 0:
    print(f'{n1} é negativo e {n2} é positivo')
  else:
    print('Esse valor não é um número')

elif saber == 'inteiro ou decimal':
  if n1 % 1 == 0 and n2 % 1 == 0:
    print(f'{n1} é um número inteiro e {n2} também')
  elif n1 % 1 != 0 and n2 % 1 != 0:
    print(f'{n1} é decimal e {n2} também')
  elif n1 % 1 == 0 and n2 % 1 != 0:
    print(f'{n1} é inteiro e {n2} é decimal')
  elif n1 % 1 != 0 and n2 % 1 == 0:
    print(f'{n1} é decimal e {n2} é inteiro')

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# Triângulo Equilátero: três lados iguais;
# Triângulo Isósceles: quaisquer dois lados iguais;
# Triângulo Escaleno: três lados diferentes.

# %%
l1 = int(input('Digite o valor do l1: '))
l2 = int(input('Digite o valor do l2: '))
l3 = int(input('Digite o valor do l3: '))

if l1 + l2 > l3 and l1 + l3 >= l2 and l2 + l3 > l1:
  if l1 == l2 == l3:
    print('É um triangulo equilatero')
  elif l1 == l2 or l3 == l2 or l3 == l1:
    print('É um triangulo isóceles')
  elif l1 != l2 != l3:
    print('É um triangulo escaleno')
else:
  print('Não é um triângulo')
# Out:
# Digite o valor do l1: 1
# Digite o valor do l2: 2
# Digite o valor do l3: 6
# Não é um triângulo

# %% [markdown]
# 12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
# O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
# O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
mensagem = input('Qual combustível (etanol) ou (diesel): ').strip()
combustiveis = ('etanol, diesel')

if mensagem == 'etanol':
  print('Você escolheu etanol')

  litros_e = float(input('Digite a quantidade de Litros: '))
  if litros_e <= 15 and litros_e > 0:
   valor_pagar = (litros_e * 1.70) - (litros_e * 0.02)
   print(f'O valor a ser pago com o desconto de 2% é {valor_pagar}')
  elif litros_e > 15:
    valor_pagar = (litros_e * 1.70) - (litros_e * 0.02)
    print(f'O valor a ser pago com o desconto de 4% é {valor_pagar}')
  else:
    print('Valor invalido')

elif mensagem == 'diesel':
  print('Você escolheu diesel')

  litros_d = float(input('Digite a quantidade de Litros: '))
  if litros_d <= 15 and litros_d > 0:
   valor_pagar = (litros_d * 2) - (litros_d * 0.03)
   print(f'O valor a ser pago com o desconto de 3% é {valor_pagar}')
  elif litros_d > 15:

    valor_pagar = (litros_d * 2) - (litros_d * 0.05)
    print(f'O valor a ser pago com o desconto de 5% é {valor_pagar}')
  else:
    print('Valor invalido')

else:
  print('Não trabalhamos com esse combústível')

# %% [markdown]
# 13) Em uma empresa de venda de imóveis você precisa criar um código que analise os dados de vendas anuais para ajudar a diretoria na tomada de decisão. O código precisa coletar os dados de quantidade de venda durante os anos de 2022 e 2023 e fazer um cálculo de variação percentual. A partir do valor da variação, deve ser enviada às seguintes sugestões:
#
# Para variação acima de 20%: bonificação para o time de vendas.
# Para variação entre 2% e 20%: pequena bonificação para time de vendas.
# Para variação entre 2% e -10%: planejamento de políticas de incentivo às vendas.
# Para variação abaixo de -10%: corte de gastos.

# %%
q_2022 = int(input('Digite a quantidade de vendas dos anos de 2022: '))
q_2023 = int(input('Digite a quantidade de vendas dos anos de 2023: '))
vp = ((q_2023 - q_2022) / q_2022) * 100

if vp >= 20:
  print('Bonificação para o time de Vendas')
elif vp >= 2 and vp <= 20:
  print('Pequena bonificação para o time de vendas')
elif vp >= -10 and vp <= 2:
  print('Planejamento de políticas de incentivo às vendas')
elif vp <= -10:
  print('Corte de Gastos')
else:
  print('Valor inválido')
